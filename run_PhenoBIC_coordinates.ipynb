# %%
from PhenoBIC_coordinates import run_PhenoBIC

# %%
run_PhenoBIC(
    image_path=r"d:\8MyLym\stitched_OMETIFFs\8MyLym_1_RU22-00361G_Scan1_Stitched.ome.tif",
    measurements_csv_path=r"d:\8MyLym\PhenoBIC_QuPath_testing\messing_around\measurements_CSVs\8MyLym_1_RU22-00361G_Scan1.csv",
    channel_indices=[6,8],
    channel_names=['CD8','CD4'],
    out_dir_path=r"d:\8MyLym\PhenoBIC_QuPath_testing\messing_around\out",
    model_path=r"d:\8MyLym\PhenoBIC_QuPath_testing\PhenoBIC_model1.keras")
# Out:
# [PhenoBIC] Computing normalization percentiles from bounds (channel 6)...
# [PhenoBIC] Normalization from bounds: min=0.00, max=56.99 (channel 6, 65995 cells)
# [PhenoBIC] Wrote min normalization: d:\8MyLym\PhenoBIC_QuPath_testing\messing_around\out\min_normalization\8MyLym_1_RU22-00361G_Scan1_Stitched.ome.json
# [PhenoBIC] Wrote max normalization: d:\8MyLym\PhenoBIC_QuPath_testing\messing_around\out\max_normalization\8MyLym_1_RU22-00361G_Scan1_Stitched.ome.json
# [PhenoBIC] Loading model: PhenoBIC_model1.keras
# [PhenoBIC] Image: 8MyLym_1_RU22-00361G_Scan1_Stitched.ome.tif — 65995 cells, tile 10000 px, overlap 138 px, 4x3 tiles
# ...
# 41/41 [==============================] - 1s 13ms/step
# [PhenoBIC] Tile (1,1)/4x3 — 9308 cells done (9308/65995)
# 8/8 [==============================] - 1s 55ms/step
# [PhenoBIC] Tile (2,1)/4x3 — 247 cells done (9555/65995)
# ...
# 113/113 [==============================] - 1s 12ms/step
# [PhenoBIC] Tile (2,2)/4x3 — 11606 cells done (21161/65995)
# ...

# %%
run_PhenoBIC(
    image_path=r"d:\8MyLym\stitched_OMETIFFs\8MyLym_1_RU22-00361G_Scan1_Stitched.ome.tif",
    measurements_csv_path=r"d:\8MyLym\PhenoBIC_QuPath_testing\messing_around\measurements_CSVs\8MyLym_1_RU22-00361G_Scan1.csv",
    channel_index=6,
    channel_name='CD8',
    out_dir_path=r"d:\8MyLym\PhenoBIC_QuPath_testing\messing_around\out",
    model_path=r"d:\8MyLym\PhenoBIC_QuPath_testing\PhenoBIC_model1.keras")
# Out:
# [PhenoBIC] Computing normalization percentiles from bounds (channel 6)...
# [PhenoBIC] Normalization from bounds: min=0.00, max=56.99 (channel 6, 65995 cells)
# [PhenoBIC] Wrote min normalization: d:\8MyLym\PhenoBIC_QuPath_testing\messing_around\out\min_normalization\8MyLym_1_RU22-00361G_Scan1_Stitched.ome.json
# [PhenoBIC] Wrote max normalization: d:\8MyLym\PhenoBIC_QuPath_testing\messing_around\out\max_normalization\8MyLym_1_RU22-00361G_Scan1_Stitched.ome.json
# [PhenoBIC] Loading model: PhenoBIC_model1.keras
# [PhenoBIC] Image: 8MyLym_1_RU22-00361G_Scan1_Stitched.ome.tif — 65995 cells, tile 10000 px, overlap 138 px, 4x3 tiles
# ...
# 41/41 [==============================] - 1s 15ms/step
# [PhenoBIC] Tile (1,1)/4x3 — 9308 cells done (9308/65995)
# 8/8 [==============================] - 1s 58ms/step
# [PhenoBIC] Tile (2,1)/4x3 — 247 cells done (9555/65995)
# ...
# 113/113 [==============================] - 2s 15ms/step
# [PhenoBIC] Tile (2,2)/4x3 — 11606 cells done (21161/65995)
# ...
