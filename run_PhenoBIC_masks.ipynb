# %% [markdown]
# # Requirements

# %% [markdown]
# Required file directory structure of multiplex channels and cell segmentation masks:
#
#
#     |-{Sample base}
#     ||-cell_segmentations
#     |||-{Patch_1}.tiff (or .tif)
#     |||-{Patch_2}.tiff (or .tif)
#     |||-{Patch_3}.tiff (or .tif)
#     ||-multiplex_images
#     |||-{Patch_1}
#     ||||-{Channel_1}.tiff (or .tif)
#     ||||-{Channel_2}.tiff (or .tif)
#     ||||-{Channel_3}.tiff (or .tif)
#     |||-{Patch_2}
#     ||||-{Channel_1}.tiff (or .tif)
#     ||||-{Channel_2}.tiff (or .tif)
#     ||||-{Channel_3}.tiff (or .tif)
#     |||-{Patch_3}
#     ||||-{Channel_1}.tiff (or .tif)
#     ||||-{Channel_2}.tiff (or .tif)
#     ||||-{Channel_3}.tiff (or .tif)
#
# Replace {Sample base}, {Patch_XX}, and {Channel_XX} to match your naming convention for samples, patches/tiles, and marker channels.
# Results are stored in `{Sample base}/PhenoBIC_output`
#
# Download the PhenoBIC `.keras` model from [here](https://github.com/your-org/qupath-extension-phenobic/releases)
#
# Sample data are shown in XXXX

# %% [markdown]
# # Run code

# %%
from PhenoBIC.PhenoBIC_masks import run_PhenoBIC

# %%
# See all the optional inputs for PhenoBIC inference function
# help(run_PhenoBIC)

# %%
run_PhenoBIC(
        # File path to {Sample_base} as shown above
        base_dir=r"c:\Users\Lumas\Downloads\PhenoBIC_inhouse_datasets\internal_val_WSIs\internal_val_WSIs\WSI1",
        # Must match exactly with channel names in file structure as shown above
        channels=['CD8'],
        model_path=r"d:\8MyLym\phen_classifiers\manu_classifiers\PhenoBIC_model1.keras",
        )
# Out:
# [PhenoBIC] Computing normalization percentiles ...
# [PhenoBIC] Computing normalization percentiles for patch 1 / 40
# [PhenoBIC] Computing normalization percentiles for patch 2 / 40
# [PhenoBIC] Computing normalization percentiles for patch 3 / 40
# [PhenoBIC] Computing normalization percentiles for patch 4 / 40
# [PhenoBIC] Computing normalization percentiles for patch 5 / 40
# [PhenoBIC] Computing normalization percentiles for patch 6 / 40
# [PhenoBIC] Computing normalization percentiles for patch 7 / 40
# [PhenoBIC] Computing normalization percentiles for patch 8 / 40
# [PhenoBIC] Computing normalization percentiles for patch 9 / 40
# [PhenoBIC] Computing normalization percentiles for patch 10 / 40
# [PhenoBIC] Computing normalization percentiles for patch 11 / 40
# [PhenoBIC] Computing normalization percentiles for patch 12 / 40
# [PhenoBIC] Computing normalization percentiles for patch 13 / 40
# [PhenoBIC] Computing normalization percentiles for patch 14 / 40
# ...
