# %% [markdown]
# # Requirements

# %% [markdown]
# - XX

# %% [markdown]
# # Run code

# %%
from PhenoBIC.PhenoBIC_masks import run_PhenoBIC

# %%
# See all the optional inputs for PhenoBIC inference function
# help(run_PhenoBIC)

# %%
run_PhenoBIC(
        base_dir=r"d:\8MyLym\trial_CiP_mask_inference\TRYING STUFF\HT_validation_base\00361G",
        channels=['CD8'],
        model_path=r"d:\8MyLym\PhenoBIC_QuPath_testing\PhenoBIC_model1.keras",
        )
# Out:
# 00361G_y_0_x_0 CD8
# 00361G_y_0_x_14940 CD8
# 00361G_y_0_x_19920 CD8
# 00361G_y_0_x_4980 CD8
# 00361G_y_0_x_9960 CD8
# 00361G_y_14940_x_0 CD8
# 00361G_y_14940_x_14940 CD8
# 00361G_y_14940_x_19920 CD8
# 00361G_y_14940_x_4980 CD8
# 00361G_y_14940_x_9960 CD8
# 00361G_y_19920_x_0 CD8
# 00361G_y_19920_x_14940 CD8
# 00361G_y_19920_x_19920 CD8
# 00361G_y_19920_x_4980 CD8
# 00361G_y_19920_x_9960 CD8
# 00361G_y_24900_x_0 CD8
# 00361G_y_24900_x_14940 CD8
# 00361G_y_24900_x_19920 CD8
# 00361G_y_24900_x_4980 CD8
# 00361G_y_24900_x_9960 CD8
# 00361G_y_29880_x_0 CD8
# 00361G_y_29880_x_14940 CD8
# 00361G_y_29880_x_19920 CD8
# 00361G_y_29880_x_4980 CD8
# 00361G_y_29880_x_9960 CD8
# 00361G_y_34860_x_0 CD8
# 00361G_y_34860_x_14940 CD8
# 00361G_y_34860_x_19920 CD8
# 00361G_y_34860_x_4980 CD8
# 00361G_y_34860_x_9960 CD8
# 00361G_y_4980_x_0 CD8
# 00361G_y_4980_x_14940 CD8
# 00361G_y_4980_x_19920 CD8
# 00361G_y_4980_x_4980 CD8
# 00361G_y_4980_x_9960 CD8
# 00361G_y_9960_x_0 CD8
# 00361G_y_9960_x_14940 CD8
# ...
