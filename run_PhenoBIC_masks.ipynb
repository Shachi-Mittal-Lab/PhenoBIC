# %% [markdown]
# # Requirements

# %% [markdown]
# Required file directory structure of multiplex channels and cell segmentation masks:
#
#
#     |-{Sample base}
#     ||-cell_segmentations
#     |||-{Patch_1}.tiff (or .tif)
#     |||-{Patch_2}.tiff (or .tif)
#     |||-{Patch_3}.tiff (or .tif)
#     ||-multiplex_images
#     |||-{Patch_1}
#     ||||-{Channel_1}.tiff (or .tif)
#     ||||-{Channel_2}.tiff (or .tif)
#     ||||-{Channel_3}.tiff (or .tif)
#     |||-{Patch_2}
#     ||||-{Channel_1}.tiff (or .tif)
#     ||||-{Channel_2}.tiff (or .tif)
#     ||||-{Channel_3}.tiff (or .tif)
#     |||-{Patch_3}
#     ||||-{Channel_1}.tiff (or .tif)
#     ||||-{Channel_2}.tiff (or .tif)
#     ||||-{Channel_3}.tiff (or .tif)
#
# Replace {Sample base}, {Patch_XX}, and {Channel_XX} to match your naming convention for samples, patches/tiles, and marker channels.
#
# Sample data are shown in XXXX

# %% [markdown]
# # Run code

# %%
# Need to add skimage to environment YML file
from PhenoBIC.PhenoBIC_masks import run_PhenoBIC

# %%
# See all the optional inputs for PhenoBIC inference function
# help(run_PhenoBIC)

# %%
run_PhenoBIC(
        # File path to {Sample_base} as shown above
        base_dir=r"d:\8MyLym\PhenoBIC_QuPath\AIR4_TMA",
        # Must match exactly with channel names in file structure as shown above
        channels=['CD8', 'CD20'],
        model_path=r"d:\8MyLym\phen_classifiers\manu_classifiers\PhenoBIC_model1.keras",
        )
# Out:
# [PhenoBIC] Computing normalization percentiles ...
# [PhenoBIC] Computing normalization percentiles for patch 1 / 2
# [PhenoBIC] Computing normalization percentiles for patch 2 / 2
# [PhenoBIC] Wrote min normalization: d:\8MyLym\PhenoBIC_QuPath\AIR4_TMA\PhenoBIC_output\normalization_min_values.json
# [PhenoBIC] Wrote max normalization: d:\8MyLym\PhenoBIC_QuPath\AIR4_TMA\PhenoBIC_output\normalization_max_values.json
# [PhenoBIC] Loading model: PhenoBIC_model1.keras
# [PhenoBIC] Processing patch 1 / 2: Abishek_tiles_core_5_5
# [PhenoBIC] Processing channel 1 / 2: CD8
# 125/125 [==============================] - 40s 10ms/step
# [PhenoBIC] Processed 4000 / 13403 cells
# 125/125 [==============================] - 1s 11ms/step
# [PhenoBIC] Processed 8000 / 13403 cells
# 125/125 [==============================] - 1s 11ms/step
# [PhenoBIC] Processed 12000 / 13403 cells
# 44/44 [==============================] - 1s 12ms/step
# [PhenoBIC] Processed 13403 / 13403 cells
# [PhenoBIC] Processed all cells for patch: Abishek_tiles_core_5_5 & channel: CD8
# [PhenoBIC] Processing channel 2 / 2: CD20
# 125/125 [==============================] - 1s 11ms/step
# [PhenoBIC] Processed 4000 / 13403 cells
# 125/125 [==============================] - 1s 11ms/step
# [PhenoBIC] Processed 8000 / 13403 cells
# 125/125 [==============================] - 1s 11ms/step
# [PhenoBIC] Processed 12000 / 13403 cells
# 44/44 [==============================] - 1s 12ms/step
# [PhenoBIC] Processed 13403 / 13403 cells
# [PhenoBIC] Processed all cells for patch: Abishek_tiles_core_5_5 & channel: CD20
# [PhenoBIC] Processing patch 2 / 2: Lizzie_tiles_core_8_5
# [PhenoBIC] Processing channel 1 / 2: CD8
# 125/125 [==============================] - 1s 11ms/step
# [PhenoBIC] Processed 4000 / 10473 cells
# 125/125 [==============================] - 1s 11ms/step
# [PhenoBIC] Processed 8000 / 10473 cells
# 78/78 [==============================] - 1s 12ms/step
# [PhenoBIC] Processed 10473 / 10473 cells
# [PhenoBIC] Processed all cells for patch: Lizzie_tiles_core_8_5 & channel: CD8
# [PhenoBIC] Processing channel 2 / 2: CD20
# 125/125 [==============================] - 1s 11ms/step
# [PhenoBIC] Processed 4000 / 10473 cells
# 125/125 [==============================] - 1s 11ms/step
# [PhenoBIC] Processed 8000 / 10473 cells
# 78/78 [==============================] - 1s 11ms/step
# [PhenoBIC] Processed 10473 / 10473 cells
# [PhenoBIC] Processed all cells for patch: Lizzie_tiles_core_8_5 & channel: CD20
